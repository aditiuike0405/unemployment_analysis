# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_csv("Unemployment in India.csv")

# %%
df
# Out:
#               Region         Date  Frequency  \
# 0     Andhra Pradesh   31-05-2019    Monthly
# 1     Andhra Pradesh   30-06-2019    Monthly
# 2     Andhra Pradesh   31-07-2019    Monthly
# 3     Andhra Pradesh   31-08-2019    Monthly
# 4     Andhra Pradesh   30-09-2019    Monthly
# ...              ...          ...        ...
# 1001     West Bengal   30-06-2020    Monthly
# 1002     West Bengal   31-07-2020    Monthly
# 1003     West Bengal   31-08-2020    Monthly
# 1004     West Bengal   30-09-2020    Monthly
# 1005     West Bengal   31-10-2020    Monthly
#
#        Estimated Unemployment Rate (%)   Estimated Employed  \
# 0                                 3.65             11999139
# 1                                 3.05             11755881
# 2                                 3.75             12086707
# 3                                 3.32             12285693
# 4                                 5.17             12256762
# ...

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                       1006.000000         1.006000e+03
# mean                          11.900099         9.004051e+06
# std                           10.742662         1.020988e+07
# min                            0.000000         4.942000e+04
# 25%                            4.682500         1.651543e+06
# 50%                            8.880000         5.544036e+06
# 75%                           16.082500         1.287982e+07
# max                           76.740000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   Longitude    Latitude
# count                               1006.000000  994.000000  994.000000
# mean                                  42.361362   22.788537   80.487174
# std                                    8.033882    6.232726    5.785773
# min                                   13.330000   10.850500   71.192400
# ...

# %%
df.isnull()
# Out:
#       Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0      False  False       False                             False
# 1      False  False       False                             False
# 2      False  False       False                             False
# 3      False  False       False                             False
# 4      False  False       False                             False
# ...      ...    ...         ...                               ...
# 1001   False  False       False                             False
# 1002   False  False       False                             False
# 1003   False  False       False                             False
# 1004   False  False       False                             False
# 1005   False  False       False                             False
#
#        Estimated Employed   Estimated Labour Participation Rate (%)   Area  \
# 0                   False                                     False  False
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1001    False
# 1002    False
# 1003    False
# 1004    False
# 1005    False
# Length: 1006, dtype: bool

# %%
df.isnull().sum()
# Out:
# Region                                       0
#  Date                                        0
#  Frequency                                   0
#  Estimated Unemployment Rate (%)             0
#  Estimated Employed                          0
#  Estimated Labour Participation Rate (%)     0
# Area                                         0
# Longitude                                   12
# Latitude                                    12
# dtype: int64

# %%
df_cleaned = df.dropna(subset=['Longitude', 'Latitude'])
df=df_cleaned.copy()

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# Longitude                                   0
# Latitude                                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994 entries, 0 to 1005
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    994 non-null    object
#  1    Date                                     994 non-null    object
#  2    Frequency                                994 non-null    object
#  3    Estimated Unemployment Rate (%)          994 non-null    float64
#  4    Estimated Employed                       994 non-null    int64
#  5    Estimated Labour Participation Rate (%)  994 non-null    float64
#  6   Area                                      994 non-null    object
#  7   Longitude                                 994 non-null    float64
#  8   Latitude                                  994 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 77.7+ KB

# %%
df.corr()
# Out:
#                                            Estimated Unemployment Rate (%)  \
#  Estimated Unemployment Rate (%)                                  1.000000
#  Estimated Employed                                              -0.206567
#  Estimated Labour Participation Rate (%)                         -0.019156
# Longitude                                                         0.200297
# Latitude                                                          0.021133
#
#                                            Estimated Employed  \
#  Estimated Unemployment Rate (%)                    -0.206567
#  Estimated Employed                                  1.000000
#  Estimated Labour Participation Rate (%)            -0.027216
# Longitude                                           -0.097299
# Latitude                                            -0.096534
#
#                                            Estimated Labour Participation Rate (%)  \
# ...

# %%
df.columns.tolist()
# Out:
# ['Region',
#  ' Date',
#  ' Frequency',
#  ' Estimated Unemployment Rate (%)',
#  ' Estimated Employed',
#  ' Estimated Labour Participation Rate (%)',
#  'Area',
#  'Longitude',
#  'Latitude']

# %%
df[' Date'] = pd.to_datetime(df[' Date'].str.strip(), format='%d-%m-%Y')

# %%
numeric_columns = [' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)']
correlation_matrix = df[numeric_columns].corr()
pastel_palette = sns.color_palette("pastel")
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap=pastel_palette, fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=' Date', y=' Estimated Unemployment Rate (%)', hue='Region', data=df)
plt.title('Estimated Unemployment Rate Over Time by Region')
plt.xlabel('Date')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.legend(title='Region', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
boxplot = sns.boxplot(x='Region', y=' Estimated Unemployment Rate (%)', data=df)
plt.title('Boxplot of Estimated Unemployment Rate by Region')
plt.xlabel('Region')
plt.ylabel('Estimated Unemployment Rate (%)')

boxplot.set_xticklabels(boxplot.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.violinplot(x='Area', y=' Estimated Unemployment Rate (%)', data=df, inner='quartile')
plt.title('Distribution of Estimated Unemployment Rate by Area')
plt.xlabel('Area')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.show()

# %%
numeric_columns = [' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)']
pairplot = sns.pairplot(df[numeric_columns], kind='scatter')
pairplot.fig.suptitle('Scatter Plot Matrix for Selected Numeric Columns', y=1.02)
plt.show()

# %%
# Geographical scatter plot of regions
plt.figure(figsize=(14, 10))
sns.scatterplot(x='Longitude', y='Latitude', hue='Region', size=' Estimated Employed', sizes=(20, 200), data=df, palette='Set2', alpha=0.7)
plt.title('Geographical Scatter Plot of Regions')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(loc='upper right')
plt.show()
